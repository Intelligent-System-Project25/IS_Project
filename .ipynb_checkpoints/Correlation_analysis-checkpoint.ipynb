# %% [markdown]
# This a correlation analysis of the key numerical features in the dataset related to tropical storms. The goal is to identify potential relationships between variables such as wind speed, pressure, damage, and other numerical features.

# %% [markdown]
# Loading the dataset csv into data frame and inspect the first few rows to understand its structure.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
dataset = pd.read_csv("completed_dataset_for_IS_project_25.csv")

print("From Dataset: Completed dataset")
print(dataset.head(10))
# Out:
# From Dataset: Completed dataset
#    Year  MONTH  DAY   LAT  LONG  WIND_KTS  PRESSURE CAT  Shape_Leng Country  \
# 0  1880      8   11  23.0 -91.9        70         0  H1    0.806226  Mexico
# 1  1880      8   11  23.4 -92.6        80         0  H1    0.761577  Mexico
# 2  1880      8   11  23.7 -93.3        80         0  H1    0.583095  Mexico
# 3  1880      8   12  24.0 -93.8        90         0  H2    0.670820  Mexico
# 4  1880      9    6  23.9 -88.6        40         0  TS    0.360555  Mexico
# 5  1880      8   10  22.0 -89.6        60         0  TS    0.854400  Mexico
# 6  1880      8    9  21.0 -87.4        70         0  H1    0.761577  Mexico
# 7  1880      8   10  21.3 -88.1        60         0  TS    0.854400  Mexico
# 8  1880      8   10  21.6 -88.9        50         0  TS    0.806226  Mexico
# 9  1880     10    6  21.4 -87.3        50         0  TS    0.800000  Mexico
#
#    ...   Mar   Apr  May   Jun   Jul   Aug   Sep   Oct   Nov   Dec
# 0  ... -0.09 -0.17 -0.1 -0.21 -0.18 -0.11 -0.15 -0.24 -0.22 -0.18
# 1  ... -0.09 -0.17 -0.1 -0.21 -0.18 -0.11 -0.15 -0.24 -0.22 -0.18
# 2  ... -0.09 -0.17 -0.1 -0.21 -0.18 -0.11 -0.15 -0.24 -0.22 -0.18
# 3  ... -0.09 -0.17 -0.1 -0.21 -0.18 -0.11 -0.15 -0.24 -0.22 -0.18
# 4  ... -0.09 -0.17 -0.1 -0.21 -0.18 -0.11 -0.15 -0.24 -0.22 -0.18
# 5  ... -0.09 -0.17 -0.1 -0.21 -0.18 -0.11 -0.15 -0.24 -0.22 -0.18
# 6  ... -0.09 -0.17 -0.1 -0.21 -0.18 -0.11 -0.15 -0.24 -0.22 -0.18
# 7  ... -0.09 -0.17 -0.1 -0.21 -0.18 -0.11 -0.15 -0.24 -0.22 -0.18
# 8  ... -0.09 -0.17 -0.1 -0.21 -0.18 -0.11 -0.15 -0.24 -0.22 -0.18
# 9  ... -0.09 -0.17 -0.1 -0.21 -0.18 -0.11 -0.15 -0.24 -0.22 -0.18
#
# [10 rows x 23 columns]

# %% [markdown]
# Before the analysis, we must check the basic summary statistics of the numerical columns to better understand the data distribution.

# %%
numeric_df = dataset.select_dtypes(include=['float64', 'int64'])

# Display basic statistics for numeric columns
numeric_df.describe()
# Out:
#                Year         MONTH           DAY           LAT          LONG  \
# count  52656.000000  52656.000000  52656.000000  52656.000000  52656.000000
# mean    1963.141826      8.501937     15.890022     23.642867    -86.212449
# std       35.909454      1.380465      8.802759      9.512564     36.878742
# min     1880.000000      1.000000      1.000000      4.200000   -180.000000
# 25%     1941.000000      8.000000      8.000000     16.200000   -110.700000
# 50%     1972.000000      9.000000     16.000000     21.300000    -84.600000
# 75%     1992.000000      9.000000     23.000000     29.800000    -64.400000
# max     2008.000000     12.000000     31.000000     69.000000    180.000000
#
#            WIND_KTS      PRESSURE    Shape_Leng  CO2 emission (Tons)  \
# count  52656.000000  52656.000000  52656.000000         5.265600e+04
# mean      54.021137    392.746069      1.194504         3.681439e+10
# std       25.238544    485.291884      0.845690         8.179390e+10
# min       10.000000      0.000000      0.000000         0.000000e+00
# 25%       35.000000      0.000000      0.700000         6.906640e+06
# 50%       45.000000      0.000000      1.004988         2.648858e+09
# 75%       70.000000    992.000000      1.421267         1.215048e+10
# max      165.000000   1024.000000     11.180340         3.530000e+11
#
#                 Jan  ...           Mar           Apr           May  \
# count  52656.000000  ...  52656.000000  52656.000000  52656.000000
# mean       0.116301  ...      0.146256      0.112056      0.100206
# std        0.359146  ...      0.356719      0.318158      0.299611
# min       -0.810000  ...     -0.630000     -0.580000     -0.550000
# 25%       -0.150000  ...     -0.150000     -0.140000     -0.140000
# 50%        0.080000  ...      0.100000      0.100000      0.110000
# 75%        0.390000  ...      0.470000      0.340000      0.330000
# max        1.020000  ...      0.880000      0.770000      0.690000
#
#                 Jun           Jul           Aug           Sep           Oct  \
# count  52656.000000  52656.000000  52656.000000  52656.000000  52656.000000
# mean       0.090699      0.102566      0.097883      0.099385      0.115567
# std        0.307962      0.285277      0.294818      0.293778      0.302885
# min       -0.520000     -0.510000     -0.550000     -0.580000     -0.580000
# 25%       -0.140000     -0.110000     -0.130000     -0.120000     -0.080000
# 50%        0.030000      0.040000      0.050000      0.060000      0.090000
# 75%        0.370000      0.330000      0.350000      0.340000      0.330000
# max        0.770000      0.650000      0.710000      0.710000      0.750000
#
#                 Nov           Dec
# count  52656.000000  52656.000000
# mean       0.109884      0.100033
# std        0.315836      0.331759
# min       -0.550000     -0.820000
# 25%       -0.080000     -0.140000
# 50%        0.050000      0.080000
# 75%        0.300000      0.380000
# max        0.740000      0.790000
#
# [8 rows x 21 columns]

# %% [markdown]
# We'll now calculate the correlation matrix for the numeric columns in the dataset. This matrix will show pairwise correlation coefficients between different features.

# %%
# Calculate the correlation matrix
corr_matrix = numeric_df.corr()
corr_matrix
# Out:
#                          Year     MONTH       DAY       LAT      LONG  \
# Year                 1.000000 -0.131170  0.026196 -0.242001 -0.239545
# MONTH               -0.131170  1.000000 -0.200987  0.152080  0.204146
# DAY                  0.026196 -0.200987  1.000000 -0.008218 -0.041128
# LAT                 -0.242001  0.152080 -0.008218  1.000000  0.428941
# LONG                -0.239545  0.204146 -0.041128  0.428941  1.000000
# WIND_KTS            -0.128157  0.093366 -0.008548  0.045653  0.098890
# PRESSURE             0.656168 -0.011618  0.022403  0.002759 -0.020639
# Shape_Leng          -0.094343  0.058983 -0.007179  0.478333  0.248866
# CO2 emission (Tons)  0.272332 -0.095308  0.018811  0.074727 -0.310212
# Jan                  0.806127 -0.077606  0.018729 -0.160226 -0.160859
# Feb                  0.785146 -0.073447  0.025039 -0.139655 -0.143658
# Mar                  0.816274 -0.083402  0.027803 -0.161027 -0.168215
# Apr                  0.824170 -0.080479  0.021470 -0.158419 -0.161798
# May                  0.832666 -0.077254  0.023042 -0.166072 -0.176217
# Jun                  0.836982 -0.074274  0.020124 -0.156568 -0.156021
# Jul                  0.825111 -0.079048  0.022283 -0.151495 -0.152227
# Jun                  0.861634  ...  0.911517  0.943578  0.942369  1.000000
# Jul                  0.856603  ...  0.909307  0.933291  0.945006  0.957154
# Aug                  0.857908  ...  0.883783  0.911200  0.920737  0.939921
# Sep                  0.845816  ...  0.870539  0.908561  0.914480  0.930494
# Oct                  0.818806  ...  0.873314  0.891575  0.889227  0.906150
# Nov                  0.783473  ...  0.859123  0.878763  0.862942  0.895181
# Dec                  0.766242  ...  0.820422  0.861641  0.863101  0.900823
#
#                           Jul       Aug       Sep       Oct       Nov  \
# Year                 0.825111  0.822956  0.816117  0.794154  0.790563
# MONTH               -0.079048 -0.071682 -0.069393 -0.063838 -0.059438
# DAY                  0.022283  0.022275  0.014097  0.022843  0.017242
# LAT                 -0.151495 -0.147506 -0.153543 -0.138994 -0.130335
# LONG                -0.152227 -0.143996 -0.148993 -0.129721 -0.129353
# WIND_KTS            -0.094893 -0.095561 -0.100570 -0.103287 -0.106595
# PRESSURE             0.730580  0.710366  0.693952  0.688928  0.680923
# Shape_Leng          -0.057421 -0.055711 -0.057638 -0.056266 -0.054812
# CO2 emission (Tons)  0.246372  0.245150  0.258125  0.253118  0.252099
# Jan                  0.856603  0.857908  0.845816  0.818806  0.783473
# Feb                  0.881539  0.865167  0.845217  0.817191  0.807016
# Mar                  0.909307  0.883783  0.870539  0.873314  0.859123
# Apr                  0.933291  0.911200  0.908561  0.891575  0.878763
# May                  0.945006  0.920737  0.914480  0.889227  0.862942
# Jun                  0.957154  0.939921  0.930494  0.906150  0.895181
# Jul                  1.000000  0.947826  0.942526  0.914179  0.900277
# Aug                  0.947826  1.000000  0.951267  0.930011  0.904459
# Sep                  0.942526  0.951267  1.000000  0.951484  0.932445
# Oct                  0.914179  0.930011  0.951484  1.000000  0.942186
# Nov                  0.900277  0.904459  0.932445  0.942186  1.000000
# Dec                  0.891982  0.894931  0.902121  0.902763  0.910793
#
#                           Dec
# Year                 0.793073
# MONTH               -0.074366
# DAY                  0.019957
# LAT                 -0.148207
# LONG                -0.151873
# WIND_KTS            -0.105320
# PRESSURE             0.667776
# Shape_Leng          -0.059510
# CO2 emission (Tons)  0.249407
# Jan                  0.766242
# Feb                  0.774591
# Mar                  0.820422
# Apr                  0.861641
# May                  0.863101
# Jun                  0.900823
# Jul                  0.891982
# Aug                  0.894931
# Sep                  0.902121
# Oct                  0.902763
# Nov                  0.910793
# Dec                  1.000000
#
# [21 rows x 21 columns]

# %% [markdown]
# To better understand the relationships between the features, we will create a heatmap of the correlation matrix. This will visually show the strength of correlations between variables.

# %%
# Plotting the heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", square=True, linewidths=0.5)
plt.title("Correlation Matrix of Tropical Storm Features", fontsize=16)
plt.tight_layout()

# Saving the heatmap as an image file
plt.savefig("correlation_matrix.png")

# Show the plot
plt.show()
